# %%
# !git clone https://github.com/darraghmaguire/automatic-scoliosis-assessment.git
# Out:
# Cloning into 'automatic-scoliosis-assessment'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 107 (delta 48), reused 78 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 5.73 MiB | 17.35 MiB/s, done.
# Resolving deltas: 100% (48/48), done.

# %%
# !python /content/automatic-scoliosis-assessment/vertebra-segmentation-network/UNetTraining.py

# %%
# !rm -rf /content/automatic-scoliosis-assessment/

# %%
# !apt-get update -qq
# !apt-get install -y octave
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   aglfn at-spi2-core default-jre-headless epstool fonts-droid-fallback
#   fonts-freefont-otf fonts-noto-mono fonts-urw-base35 ghostscript gnuplot-data
#   gnuplot-qt gsettings-desktop-schemas gsfonts imagemagick-6-common info
#   install-info libamd2 libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libauthen-sasl-perl libbtf1 libcamd2 libccolamd2 libcholmod3
#   libclone-perl libcolamd2 libcombblas1.16.0 libcxsparse3 libdata-dump-perl
#   libdouble-conversion3 libemf1 libencode-locale-perl libevdev2
#   libfftw3-double3 libfftw3-long3 libfftw3-mpi3 libfftw3-single3
# ...

# %%
# !octave --version
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# GNU Octave, version 6.4.0
# Copyright (C) 2021 The Octave Project Developers.
# This is free software; see the source code for copying conditions.
# There is ABSOLUTELY NO WARRANTY; not even for MERCHANTABILITY or
# FITNESS FOR A PARTICULAR PURPOSE.
#
# Octave was configured for "x86_64-pc-linux-gnu".
#
# Additional information about Octave is available at https://www.octave.org.
#
# Please contribute if you find this software useful.
# For more information, visit https://www.octave.org/get-involved.html
#
# Read https://www.octave.org/bugs.html to learn how to submit bug reports.

# %%
# %cd automatic-scoliosis-assessment/clinical-assessment-algorithms
# Out:
# /content/automatic-scoliosis-assessment/clinical-assessment-algorithms

# %%
import numpy as np

# %%
from scipy.io import savemat

# %%
endplateLandmarks = endplateLandmarks = np.array([ [10,20],[12,20],[10,22],[12,22],[20,40],[22,40],[20,42],[22,42],[30,60],[32,60],[30,62],[32,62],[40,80],[42,80],[40,82],[42,82],[50,100],[52,100],[50,102],[52,102],[60,120],[62,120],[60,122],[62,122],[70,140],[72,140],[70,142],[72,142],[80,160],[82,160],[80,162],[82,162],[90,180],[92,180],[90,182],[92,182],[100,200],[102,200],[100,202],[102,202],[110,220],[112,220],[110,222],[112,222],[120,240],[122,240],[120,242],[122,242]], dtype=float)
centroids = np.array([ [11,21],[21,41],[31,61],[41,81], [51,101],[61,121],[71,141],[81,161], [91,181],[101,201],[111,221],[121,241] ], dtype=float)
angleLocations = np.zeros((4,1), dtype=float)
savemat("test_inputs.mat", { "endplateLandmarks": endplateLandmarks, "centroids": centroids, "angleLocations": angleLocations })

# %%
# !apt-get install -y liboctave-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# liboctave-dev is already the newest version (6.4.0-2).
# 0 upgraded, 0 newly installed, 0 to remove and 63 not upgraded.

# %%
# !octave --eval "pkg install -forge control"
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# slicot/src/../../TB01ZD.f:312:72: warning: type of ‘mb01pd’ does not match original declaration [-Wlto-type-mismatch]
#   312 |       CALL MB01PD( 'S', 'G', N, N, 0, 0, ANORM, 0, NBLK, A, LDA, INFO )
#       |                                                                        ^
# slicot/src/MB01PD.f:4:23: note: ‘mb01pd’ was previously declared here
#     4 |       SUBROUTINE MB01PD( SCUN, TYPE, M, N, KL, KU, ANRM, NBL, NROWS, A,
#       |                       ^
# slicot/src/MB01PD.f:4:23: note: code may be misoptimized unless ‘-fno-strict-aliasing’ is used
# sl_mb03rd.cc:34:9: warning: type of ‘mb03rd_’ does not match original declaration [-Wlto-type-mismatch]
#    34 |     int F77_FUNC (mb03rd, MB03RD)
#       |         ^
# slicot/src/MB03RD.f:4:23: note: return value type mismatch
#     4 |       SUBROUTINE MB03RD( JOBX, SORT, N, PMAX, A, LDA, X, LDX, NBLCKS,
#       |                       ^
# ...

# %%
# !octave --eval "pkg install -forge signal"
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# For information about changes from previous versions of the signal package, run 'news signal'.

# %%
# !octave --eval "pkg list"
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# Package Name  | Version | Installation directory
# --------------+---------+-----------------------
#      control  |   4.2.1 | /usr/share/octave/packages/control-4.2.1
#       signal  |   1.4.7 | /usr/share/octave/packages/signal-1.4.7

# %%
# !octave --eval "pkg load control; pkg load signal; disp('Packages chargés avec succès')"
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# Packages chargés avec succès

# %%
# !octave --eval "load('test_inputs.mat'); whos endplateLandmarks centroids angleLocations"
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# Variables visible from the current scope:
#
# variables in scope: top scope
#
#    Attr Name                   Size                     Bytes  Class
#    ==== ====                   ====                     =====  =====
#         endplateLandmarks     48x2                        768  double
#         centroids             12x2                        192  double
#         angleLocations         4x1                         32  double
#
# Total is 124 elements using 992 bytes

# %%
# !octave --eval "pkg load control; pkg load signal; load('test_inputs.mat'); endplateLandmarks = double(endplateLandmarks); centroids = double(centroids); angleLocations = double(angleLocations); [cobbAngles, apicalVertebrae, angleLocations, cobbEndplates] = calculateCobbAngles(endplateLandmarks, centroids, angleLocations); disp('Cobb Angles:'), disp(cobbAngles), disp('Apical Vertebrae:'), disp(apicalVertebrae)"
# Out:
# octave: X11 DISPLAY environment variable not set
# octave: disabling GUI features
# Cobb Angles:
#    0
#    0
#    0
# Apical Vertebrae:
#    2
#    9
#    0
